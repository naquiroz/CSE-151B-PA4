# %%
from pa4.experiment import Experiment

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 1
# %aimport pa4.experiment

# %%
exp_name = 'default'

exp = Experiment(exp_name)
# Out:
# loading annotations into memory...
# Done (t=1.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.47s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.95s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=1.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=1.38s)
# creating index...
# index created!
# Loading

# %%
exp.run()
# Out:
# captions type:  <class 'torch.Tensor'>
# train output size:  2
# train output:  (tensor([[[-3.7007e-02,  5.6177e-02, -5.4110e-02,  ..., -1.2963e-02,
#            1.2955e-02, -8.7094e-02],
#          [-1.4253e-01, -5.3352e-02, -9.5640e-02,  ..., -6.4170e-02,
#           -1.2236e-02, -1.7968e-02],
#          [-1.1791e-01,  6.1992e-02, -1.7362e-02,  ..., -1.6054e-01,
#            1.0238e-01, -9.9318e-02],
#          ...,
#          [ 1.9054e-01,  3.6192e-03,  9.5927e-03,  ..., -4.4197e-02,
#            2.5476e-01,  5.2384e-02],
#          [ 4.8254e-02,  7.1826e-03, -1.1053e-01,  ...,  4.6599e-02,
#           -3.2391e-03,  1.4228e-01],
#          [ 1.3741e-01,  4.6439e-02, -3.2974e-02,  ..., -6.9155e-02,
#           -9.0911e-03,  1.5761e-02]],
#
#         [[ 1.4668e-02,  4.6928e-02, -2.4171e-03,  ..., -4.2549e-02,
#            8.0912e-03, -5.8614e-02],
#          [-1.1476e-01, -5.4050e-02, -6.6894e-02,  ..., -7.8604e-02,
#           -1.2922e-02, -1.3037e-03],
#          [-1.0397e-01,  6.4840e-02,  6.8531e-03,  ..., -1.6937e-01,
#            1.0152e-01, -8.6996e-02],
#          ...,
#          [ 1.1162e-01,  1.6492e-02, -2.0320e-02,  ..., -9.2061e-02,
#           -5.5452e-03, -1.4404e-05],
#          [ 1.1092e-01,  1.5887e-01, -1.2774e-01,  ..., -9.0253e-02,
#           -2.8018e-02, -1.8376e-01],
#          [ 7.7891e-02,  2.1436e-01, -1.6702e-01,  ..., -9.4931e-02,
#           -3.9426e-02, -2.8292e-01]],
#
#         [[-9.3965e-03,  5.0607e-02, -2.3908e-02,  ..., -8.3215e-03,
#           -9.1826e-04, -2.7787e-02],
#          [-1.2460e-01, -5.0383e-02, -7.9650e-02,  ..., -6.5351e-02,
#           -1.9556e-02,  1.0659e-02],
#          [ 3.1452e-02, -3.1197e-02, -2.6212e-02,  ..., -7.7681e-02,
#           -1.9322e-01,  2.5468e-01],
#          ...,
#          [ 5.4678e-02,  2.2299e-01, -1.7006e-01,  ..., -7.8390e-02,
#           -5.2036e-02, -2.7727e-01],
#          [ 4.6079e-02,  2.4408e-01, -1.8505e-01,  ..., -8.4974e-02,
#           -5.0046e-02, -3.3029e-01],
#          [ 4.2670e-02,  2.5209e-01, -1.9034e-01,  ..., -8.6276e-02,
#           -4.8528e-02, -3.5765e-01]],
#
#         ...,
#
#         [[-8.7251e-03,  2.5122e-02, -5.4089e-02,  ..., -1.7242e-02,
#            6.5753e-02, -2.4684e-02],
#          [-1.2630e-01, -6.4074e-02, -9.5950e-02,  ..., -6.7078e-02,
#            1.4929e-02,  9.3632e-03],
#          [ 1.6664e-02, -2.3270e-01, -3.5157e-02,  ...,  1.0471e-01,
#            1.3441e-02,  9.9255e-02],
#          ...,
#          [ 4.0514e-02,  2.5736e-01, -1.9442e-01,  ..., -7.7324e-02,
#           -4.6092e-02, -3.8992e-01],
#          [ 4.0553e-02,  2.5746e-01, -1.9449e-01,  ..., -7.6939e-02,
#           -4.5997e-02, -3.8990e-01],
#          [ 4.0589e-02,  2.5752e-01, -1.9453e-01,  ..., -7.6677e-02,
#           -4.5917e-02, -3.8984e-01]],
#
#         [[-3.8827e-02,  3.1867e-02, -1.3395e-02,  ..., -2.7721e-02,
#           -4.3368e-03, -4.9696e-02],
#          [-1.4863e-01, -6.3806e-02, -7.1292e-02,  ..., -7.1566e-02,
#           -1.9994e-02, -6.6699e-04],
#          [-1.2475e-01,  5.9149e-02,  5.6278e-03,  ..., -1.6473e-01,
#            9.4843e-02, -8.7249e-02],
#          ...,
#          [ 4.0395e-02,  2.5737e-01, -1.9476e-01,  ..., -7.7165e-02,
#           -4.6017e-02, -3.9043e-01],
#          [ 4.0466e-02,  2.5745e-01, -1.9472e-01,  ..., -7.6853e-02,
#           -4.5934e-02, -3.9025e-01],
#          [ 4.0524e-02,  2.5751e-01, -1.9469e-01,  ..., -7.6632e-02,
#           -4.5867e-02, -3.9009e-01]],
#
#         [[-4.5340e-02,  3.4115e-02, -5.3144e-02,  ...,  1.2470e-02,
#            1.3121e-02, -5.3458e-02],
#          [-1.4873e-01, -5.7652e-02, -9.5763e-02,  ..., -5.5940e-02,
#           -9.4225e-03, -4.2493e-03],
#          [-6.7746e-02, -1.7281e-01, -1.4268e-02,  ..., -9.4473e-02,
#           -6.5048e-02,  2.1425e-01],
#          ...,
#          [ 4.0615e-02,  2.5732e-01, -1.9471e-01,  ..., -7.7193e-02,
#           -4.5845e-02, -3.8999e-01],
#          [ 4.0630e-02,  2.5741e-01, -1.9471e-01,  ..., -7.6848e-02,
#           -4.5816e-02, -3.8995e-01],
#          [ 4.0646e-02,  2.5748e-01, -1.9471e-01,  ..., -7.6611e-02,
#           -4.5786e-02, -3.8988e-01]]], device='cuda:0',
#        grad_fn=<CudnnRnnBackward>), (tensor([[[ 0.1374,  0.0464, -0.0330,  ..., -0.0692, -0.0091,  0.0158],
#          [ 0.0779,  0.2144, -0.1670,  ..., -0.0949, -0.0394, -0.2829],
#          [ 0.0427,  0.2521, -0.1903,  ..., -0.0863, -0.0485, -0.3576],
#          ...,
#          [ 0.0406,  0.2575, -0.1945,  ..., -0.0767, -0.0459, -0.3898],
#          [ 0.0405,  0.2575, -0.1947,  ..., -0.0766, -0.0459, -0.3901],
#          [ 0.0406,  0.2575, -0.1947,  ..., -0.0766, -0.0458, -0.3899]]],
#        device='cuda:0', grad_fn=<CudnnRnnBackward>), tensor([[[ 0.3265,  0.1012, -0.0685,  ..., -0.1123, -0.0237,  0.0356],
#          [ 0.1309,  0.4171, -0.3080,  ..., -0.2154, -0.1285, -0.5175],
#          [ 0.0715,  0.4906, -0.3606,  ..., -0.1996, -0.1540, -0.7013],
#          ...,
#          [ 0.0679,  0.5021, -0.3675,  ..., -0.1778, -0.1434, -0.8020],
#          [ 0.0678,  0.5020, -0.3678,  ..., -0.1777, -0.1432, -0.8025],
#          [ 0.0680,  0.5021, -0.3678,  ..., -0.1777, -0.1430, -0.8020]]],
#        device='cuda:0', grad_fn=<CudnnRnnBackward>)))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a33583383f44> in <module>
# ----> 1 exp.run()
#
# ~/CSE-151B-PA4/pa4/experiment.py in run(self)
#     103             start_time = datetime.now()
#     104             self.__current_epoch = epoch
# --> 105             train_loss = self.__train()
#     106             val_loss = self.__val()
#     107             self.__record_stats(train_loss, val_loss)
#
# ~/CSE-151B-PA4/pa4/experiment.py in __train(self)
#     133
#     134                 loss = self.__criterion(
# --> 135                     output.reshape(-1, output.shape[2]), captions.reshape(-1)
#     136                 )
#     137
#
# AttributeError: 'tuple' object has no attribute 'reshape'

# %%
exp.test()
